# %% [markdown]
# <img width=300 height=300 src="vacuum.webp">

# %% [markdown]
# ## CS 470 Artificial Intelligence hw1
#
# You are to edit the file hw1.py, as described in the instructions.
# We have provided a solution file, hw1a.pyc, which is compiled bytecode that you may run.
#
# Below we demonstrate the code, both with and without graphics.

# %%
from hw2 import *

# %%
gv = GraphicVacuumEnvironment(10,10,bias=0.5,color={'Agent': (200,0,0), 'Dirt': (230, 115, 40), 'Wall': (100,100,100)})

# %%
rv = TraceAgent(BetterReflexVacuumAgent())
gv.add_thing(rv)
gv.get_world()
# Out:
# [[[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]],
#  [[<Wall>],
#   [<Dirt>, <Agent>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [],
#   [<Wall>]],
#  [[<Wall>], [<Dirt>], [], [<Dirt>], [], [], [<Dirt>], [], [<Dirt>], [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [<Dirt>], [], [<Dirt>], [], [], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [], [], [<Dirt>], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>], [], [], [<Dirt>], [], [<Dirt>], [<Dirt>], [<Dirt>], [], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [],
#   [<Wall>]],
#  [[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]]]

# %%
rv.performance
# Out:
# 0

# %%
rv.location
# Out:
# (1, 1)

# %%
gv.run(10)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa34aa5ea-bd30-4468-b248-c6d30941c4d0 td {border: 1px solid white;}</style><table id="blocksa34aa5ea-bd30-4468-b248-c6d30941c4d0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px ...
# <Agent> perceives ('Dirty', 'None') and does Suck
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd97ea31e-4738-4496-a37b-5320efde21c2 td {border: 1px solid white;}</style><table id="blocksd97ea31e-4738-4496-a37b-5320efde21c2" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px ...
# <Agent> perceives ('Clean', 'None') and does Up
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd8a81a08-65f0-4dde-b5fe-f07eff4011b9 td {border: 1px solid white;}</style><table id="blocksd8a81a08-65f0-4dde-b5fe-f07eff4011b9" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px ...
# <Agent> perceives ('Clean', 'None') and does Right
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3d01985a-b2f0-4596-851f-3ab8c7966b78 td {border: 1px solid white;}</style><table id="blocks3d01985a-b2f0-4596-851f-3ab8c7966b78" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20 ...
# <Agent> perceives ('Dirty', 'None') and does Suck
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7a4ad5b9-0b51-4e89-82e0-a6d9aea96dea td {border: 1px solid white;}</style><table id="blocks7a4ad5b9-0b51-4e89-82e0-a6d9aea96dea" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20 ...
# <Agent> perceives ('Clean', 'None') and does Up
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks37395627-32aa-4996-a92b-331f05cb8ae5 td {border: 1px solid white;}</style><table id="blocks37395627-32aa-4996-a92b-331f05cb8ae5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20 ...
# <Agent> perceives ('Clean', 'None') and does Left
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfc6b006d-d27e-49d8-91f4-eaacd46bb492 td {border: 1px solid white;}</style><table id="blocksfc6b006d-d27e-49d8-91f4-eaacd46bb492" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20 ...
# <Agent> perceives ('Clean', 'None') and does Down
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7f5188eb-318c-47f5-9bbe-48fe7b196952 td {border: 1px solid white;}</style><table id="blocks7f5188eb-318c-47f5-9bbe-48fe7b196952" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height:  ...
# <Agent> perceives ('Dirty', 'None') and does Suck
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks14aefa68-ca77-4f53-b94c-88b68bea92d8 td {border: 1px solid white;}</style><table id="blocks14aefa68-ca77-4f53-b94c-88b68bea92d8" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height:  ...
# <Agent> perceives ('Clean', 'None') and does Left
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7e24f9b5-09c8-46be-b2c2-8b319a1f1ed9 td {border: 1px solid white;}</style><table id="blocks7e24f9b5-09c8-46be-b2c2-8b319a1f1ed9" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height:  ...
# <Agent> perceives ('Clean', 'None') and does Up
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf4e94536-e83a-4e4b-9a24-b1dd74c07490 td {border: 1px solid white;}</style><table id="blocksf4e94536-e83a-4e4b-9a24-b1dd74c07490" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 4]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 5]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 6]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 7]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 8]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [0, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 6]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [1, 9]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (100, 100, 100)" style="width: 20px; height: 20px;background-color: rgb(100, 100, 100);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 4]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 5]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 6]&#10;Color: (230, 115, 40)" style="width: 20px; height: 20px;background-color: rgb(230, 115, 40);"></td><td title="Index: [2, 7]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 8]&#10;Color: (230, 115, 40)" style="width: 20px; height:  ...

# %%
rv.location
# Out:
# (1, 1)

# %%
rv.performance
# Out:
# 23

# %% [markdown]
# Now we create a vacuum world without graphics.

# %%
nve = NewVacuumEnvironment(10,10,bias=0.5)

# %%
nrv = TraceAgent(BetterReflexVacuumAgent())
nve.add_thing(nrv)
nve.get_world()
# Out:
# [[[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]],
#  [[<Wall>],
#   [<Agent>],
#   [],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [],
#   [],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [], [], [<Dirt>], [], [<Dirt>], [], [<Dirt>], [], [<Wall>]],
#  [[<Wall>], [], [<Dirt>], [<Dirt>], [<Dirt>], [], [], [], [<Dirt>], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [],
#   [],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Wall>]],
#  [[<Wall>], [<Dirt>], [<Dirt>], [], [], [], [<Dirt>], [], [], [<Wall>]],
#  [[<Wall>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [<Dirt>],
#   [],
#   [<Dirt>],
#   [],
#   [],
#   [<Wall>]],
#  [[<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>],
#   [<Wall>]]]

# %%
nve.run(10)
# Out:
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Clean', 'None') and does Right
# <Agent> perceives ('Dirty', 'None') and does Suck
# <Agent> perceives ('Clean', 'None') and does Right
# <Agent> perceives ('Clean', 'None') and does Left
# <Agent> perceives ('Clean', 'None') and does Right
# <Agent> perceives ('Clean', 'None') and does Left
# <Agent> perceives ('Clean', 'None') and does Down
# <Agent> perceives ('Dirty', 'None') and does Suck

# %%
nrv.location
# Out:
# (2, 2)

# %%
nrv.performance
# Out:
# 12

# %%
main()
# Out:
# hours
# # is it greater than 0?
#  OK  got: 2 expected: <function main.<locals>.<lambda> at 0x7eade80e9260>
# NewVacuumEnvironment - Walls
#  OK  got: '[[[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]]]' expected: '[[[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [], [], [], [<Wall>]], [[<Wall>], [<Wall>], [<Wall>], [<Wall>], [<Wall>]]]'
# NewVacuumEnvironment - Dirt
#  OK  got: 150 expected: <function main.<locals>.<lambda> at 0x7eade80e9260>
# NewVacuumEnvironment - Very Clean
#  OK  got: 0 expected: 0
# NewVacuumEnvironment - Very Dirty
#  OK  got: 324 expected: 324
# TraceAgent and BetterReflexVacuumAgent
# <Agent> perceives ('Dirty', 'None') and does Suck
#  OK  got: (1, 1) expected: (1, 1)
#  OK  got: 10 expected: 10
# <Agent> perceives ('Clean', 'None') and does Left
# <Agent> perceives ('Clean', 'None') and does Left
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Clean', 'None') and does Down
# <Agent> perceives ('Dirty', 'None') and does Suck
# <Agent> perceives ('Clean', 'None') and does Left
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Clean', 'None') and does Right
# <Agent> perceives ('Dirty', 'None') and does Suck
# <Agent> perceives ('Clean', 'None') and does Down
# <Agent> perceives ('Dirty', 'None') and does Suck
# <Agent> perceives ('Clean', 'None') and does Right
# <Agent> perceives ('Dirty', 'None') and does Suck
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Dirty', 'None') and does Suck
# <Agent> perceives ('Clean', 'None') and does Left
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Clean', 'None') and does Up
# <Agent> perceives ('Clean', 'None') and does Down
# <Agent> perceives ('Clean', 'None') and does Left
#  OK  got: 45 expected: <function main.<locals>.<lambda> at 0x7eade80e9580>

# %% [markdown]
# Below we demonstrate the testing code from the end of agents.py

# %%
environment = TrivialVacuumEnvironment

# %%
agents = [ModelBasedVacuumAgent, BetterReflexVacuumAgent]

# %%
result = compare_agents(environment, agents)

# %%
result
# Out:
# [(<function agents.ModelBasedVacuumAgent()>, 15),
#  (<function hw2.BetterReflexVacuumAgent()>, -492.7)]
